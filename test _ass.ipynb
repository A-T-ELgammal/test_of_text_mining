# %% [markdown]
# # Ahmed Elgammal
# ## Notebook for analysing the reactions and opinions about mo salah

# %%
import bs4 as bs
import urllib.request
import json
import search_google.api
import pandas as pd
from nltk.tokenize import sent_tokenize, word_tokenize
import codecs
from nltk.corpus import stopwords

# %%
import nltk
nltk.download('punkt')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\muhammed\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\muhammed\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\stopwords.zip.
# True

# %%
buildargs = {
  'serviceName': 'customsearch',
  'version': 'v1',
  'developerKey': 'AIzaSyAVlz4a-ab97asqyoA4WyziYnB9rzQT3w4'
}

cseargs = {
  'q': 'mo salah',
  'cx': '006545984732507860518:c8djzdsh58u',
  'num': 10
}

# %%
results = search_google.api.results(buildargs, cseargs)
links = results.get_values('items', 'link')
links = results.links
results.save_metadata('metadata.json')
results.save_links('links.txt')

# %%
for link in links :
    print(link)
# Out:
# http://feedproxy.google.com/~r/inside-the-world-economic-forum/~3/dHDvqbGebLw/
# http://feedproxy.google.com/~r/HumanRightsEgypt/~3/tKeRULyvacA/url
# http://feedproxy.google.com/~r/time/topstories/~3/FX-REL_8csI/
# http://feedproxy.google.com/~r/daily-express-football-news/~3/JP6ViIuzjI8/Liverpool-Mo-Salah-Celebration-Chelsea-Premier-League
# http://feedproxy.google.com/~r/daily-express-football-news/~3/x0Py0vvaXZM/Liverpool-Jurgen-Klopp-Mohamed-Salah-Roberto-Firmino-rumours-Twitter-rant-Huddersfield
# http://feedproxy.google.com/~r/TheNewsNigeria2/~3/5TCS3ZpSllA/a-49369118
# http://feedproxy.google.com/~r/daily-express-sport-news/~3/RDQITyw65CY/Liverpool-news-Mohamed-Salah-Jurgen-Klopp-New-York-Time-Magazine-Premier-League-title
# http://feedproxy.google.com/~r/daily-express-world-news/~3/MM5AuyJG2Lc/Mo-Salah-statue-liverpool-egypt-cristiano-ronaldo-football
# ...

# %%
for link in links:
    url=urllib.request.urlopen(link).read()
    soup = bs.BeautifulSoup(url, 'lxml')
    pars = soup.find_all('p')
    word_list = []
    for p in pars:
        word_list.append(p)
        print(p.text)
#     for p in pars :
#         file = codecs.open('p-text.txt','w','utf-8')
#         file.write(p.text)
# Out:
# We use cookies to improve your experience on our website. By using our website you consent to all cookies in accordance with our updated Cookie Notice.
# Besides his second-minute penalty for Liverpool FC against Tottenham Hotspur FC in Madrid on 1 June, Egyptian football striker Mo Salah may have also scored a goal against prejudice, according to a new study.
# On the pitch, Salah often celebrates goals by dropping to his knees and touching his forehead to the grass in the sujood (an Islamic prayer position), while Liverpool fans have a chant that goes: “If he scores another few, then I’ll be Muslim, too”.
# But the Salah effect is having an impact beyond the stadium walls, say researchers from Stanford University, who found a drop in hate crimes around Liverpool since Salah signed with the club in June 2017.
# ...

# %%
with open ('p-tex.txt') as pt:
    tokens = sent_tokenize(pt.read())
    print(tokens)
# Out:
# ['We use cookies to improve your experience on our website.', 'By using our website you consent to all cookies in accordance with our updated Cookie Notice.', 'Besides his second-minute penalty for Liverpool FC against Tottenham Hotspur FC in Madrid on 1 June, Egyptian football striker Mo Salah may have also scored a goal against prejudice, according to a new study.', 'On the pitch, Salah often celebrates goals by dropping to his knees and touching his forehead to the grass in the sujood (an Islamic prayer position), while Liverpool fans have a chant that goes: â€œIf he scores another few, then Iâ€™ll be Muslim, tooâ€\u200c.', 'But the Salah effect is having an impact beyond the stadium walls, say researchers from Stanford University, who found a drop in hate crimes around Liverpool since Salah signed with the club in June 2017.', 'The report examined data from police departments around England, including Merseyside, the UK county in which Liverpool is located.', 'It found hate crime
# ...

# %%
stop = stopwords.words("english")
filtered = []

for word in tokens:
    if word not in stop:
        filtered.append(word)
filtered
# Out:
# ['We use cookies to improve your experience on our website.',
#  'By using our website you consent to all cookies in accordance with our updated Cookie Notice.',
#  'Besides his second-minute penalty for Liverpool FC against Tottenham Hotspur FC in Madrid on 1 June, Egyptian football striker Mo Salah may have also scored a goal against prejudice, according to a new study.',
#  'On the pitch, Salah often celebrates goals by dropping to his knees and touching his forehead to the grass in the sujood (an Islamic prayer position), while Liverpool fans have a chant that goes: â€œIf he scores another few, then Iâ€™ll be Muslim, tooâ€\u200c.',
#  'But the Salah effect is having an impact beyond the stadium walls, say researchers from Stanford University, who found a drop in hate crimes around Liverpool since Salah signed with the club in June 2017.',
#  'The report examined data from police departments around England, including Merseyside, the UK county in which Liverpool is located.',
# ...

# %% [markdown]
#     now deal with metadata

# %%
results.metadata
# Out:
# {'kind': 'customsearch#search',
#  'url': {'type': 'application/json',
#   'template': 'https://www.googleapis.com/customsearch/v1?q={searchTerms}&num={count?}&start={startIndex?}&lr={language?}&safe={safe?}&cx={cx?}&sort={sort?}&filter={filter?}&gl={gl?}&cr={cr?}&googlehost={googleHost?}&c2coff={disableCnTwTranslation?}&hq={hq?}&hl={hl?}&siteSearch={siteSearch?}&siteSearchFilter={siteSearchFilter?}&exactTerms={exactTerms?}&excludeTerms={excludeTerms?}&linkSite={linkSite?}&orTerms={orTerms?}&relatedSite={relatedSite?}&dateRestrict={dateRestrict?}&lowRange={lowRange?}&highRange={highRange?}&searchType={searchType}&fileType={fileType?}&rights={rights?}&imgSize={imgSize?}&imgType={imgType?}&imgColorType={imgColorType?}&imgDominantColor={imgDominantColor?}&alt=json'},
#  'queries': {'request': [{'title': 'Google Custom Search - mo salah',
#     'totalResults': '136000',
#     'searchTerms': 'mo salah',
#     'count': 10,
#     'startIndex': 1,
#     'inputEncoding': 'utf8',
# ...

# %%
with open('metadata.json') as d:
    d = json.load(d)
    pd.read_json(d, orient='split')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-61-d09bd1538721> in <module>()
#       1 with open('metadata.json') as d:
#       2     d = json.load(d)
# ----> 3     pd.read_json(d, orient='split')
#
# ~\Anaconda3\lib\site-packages\pandas\io\json\json.py in read_json(path_or_buf, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, numpy, precise_float, date_unit, encoding, lines, chunksize, compression)
#     406     compression = _infer_compression(path_or_buf, compression)
#     407     filepath_or_buffer, _, compression, should_close = get_filepath_or_buffer(
# --> 408         path_or_buf, encoding=encoding, compression=compression,
#     409     )
#     410
#
# ~\Anaconda3\lib\site-packages\pandas\io\common.py in get_filepath_or_buffer(filepath_or_buffer, encoding, compression, mode)
#     216     if not is_file_like(filepath_or_buffer):
# ...
